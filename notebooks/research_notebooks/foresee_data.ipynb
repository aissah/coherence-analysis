# %%
import sys

import dascore as dc
import matplotlib.pyplot as plt
import numpy as np

sys.path.insert(1, "D:\CSM\Mines_Research\tdms_reader.py_")
# from tdms_reader import *

# %%
directory = "D:\CSM\Mines_Research\Test_data\FORESEE_Aug"
spool = dc.spool(directory)

contents = spool.get_contents()
print(contents)

# %%
patch = spool[6]
array = np.array(patch.data)
array.shape

# %%
plt.figure(figsize=(10, 7))
plt.imshow(
    array[:, :7500],
    cmap="RdBu",
    aspect="auto",
    clim=(-10, 10),
    extent=[0, 60, 0, 4800],
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.colorbar()
